# %%
import pandas

# %%
df1 = pandas.read_csv("traffic.csv")

# %%
df1
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df2 = pandas.read_json("traffic.json")
# header is by default the first row
# df2 = pandas.read_json("traffic.json", header = None)

# %%
df2
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df2
# json is just like dictionaries that is it does not have any order
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
# If I want to use date as index
df2.set_index("Date")
# Out:
#       Visitors  BR    Country  Clicks        Day
# Date
# 1         1500  20        USA      20    Tuesday
# 2          700  25         UK      35  Wednesday
# 3          900  15      India      37   Thursday
# 4          400  35        USA      12     Friday
# 5          500  14     Canada      35   Saturday
# 6          700  15      India      32     Sunday
# 7          600  20      India      37     Monday
# 8          700  16        USA      40    Tuesday
# 9         1200  27        USA      52  Wednesday
# 10        1400  32  Australia      57   Thursday

# %%
df2.shape
# Out:
# (10, 6)

# %%
# All the previous changes are not permanent but you can store them in new dataframe

# %%
df3 = pandas.read_csv("traffic-commas.txt")
df3
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df4 = pandas.read_csv("traffic-semi-colons.txt")

# %%
df4 
# As you can see the semicolons are not recognised so to do that 
# we have to explicitly tell it
# Out:
#   Date;Visitors;BR;Country;Clicks;Day
# 0            1;1500;20;USA;20;Tuesday
# 1            2;700;25;UK;35;Wednesday
# 2          3;900;15;India;37;Thursday
# 3              4;400;35;USA;12;Friday
# 4         5;500;14;Canada;35;Saturday
# 5            6;700;15;India;32;Sunday
# 6            7;600;20;India;37;Monday
# 7             8;700;16;USA;40;Tuesday
# 8          9;1200;27;USA;52;Wednesday
# 9    10;1400;32;Australia;57;Thursday

# %%
df4 = pandas.read_csv("traffic-semi-colons.txt", sep = ";")
df4
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
# Indexing and slicing
# label based and Position based

# %%
df4.loc[2:5, "Country":"Day"]
# Point to be noted as we are working with labels so the end index is also 
# included unlike the lists slicing
# Out:
#   Country  Clicks       Day
# 2   India      37  Thursday
# 3     USA      12    Friday
# 4  Canada      35  Saturday
# 5   India      32    Sunday

# %%
df5 = df4.loc[2:5, "Country":"Day"]

# %%
df5
# Out:
#   Country  Clicks       Day
# 2   India      37  Thursday
# 3     USA      12    Friday
# 4  Canada      35  Saturday
# 5   India      32    Sunday

# %%
# I need all the rows for click
df4.loc[:, "Clicks"]
# Out:
# 0    20
# 1    35
# 2    37
# 3    12
# 4    35
# 5    32
# 6    37
# 7    40
# 8    52
# 9    57
# Name: Clicks, dtype: int64

# %%
# iloc which totally depends upon the index numbers similar to lists in python
df4.iloc[6:9, 1:5] # here you cannot use the labels in index-loc
# Out:
#    Visitors  BR Country  Clicks
# 6       600  20   India      37
# 7       700  16     USA      40
# 8      1200  27     USA      52

# %%
df4.drop("Day", 1) # 1 for column and 0 for rows
# Out:
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_3228\2488481775.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df4.drop("Day", 1) # 1 for column and 0 for rows
#    Date  Visitors  BR    Country  Clicks
# 0     1      1500  20        USA      20
# 1     2       700  25         UK      35
# 2     3       900  15      India      37
# 3     4       400  35        USA      12
# 4     5       500  14     Canada      35
# 5     6       700  15      India      32
# 6     7       600  20      India      37
# 7     8       700  16        USA      40
# 8     9      1200  27        USA      52
# 9    10      1400  32  Australia      57

# %%
df4
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df4.drop(9, 0)
# Out:
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_3228\3009524116.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df4.drop(9, 0)
#    Date  Visitors  BR Country  Clicks        Day
# 0     1      1500  20     USA      20    Tuesday
# 1     2       700  25      UK      35  Wednesday
# 2     3       900  15   India      37   Thursday
# 3     4       400  35     USA      12     Friday
# 4     5       500  14  Canada      35   Saturday
# 5     6       700  15   India      32     Sunday
# 6     7       600  20   India      37     Monday
# 7     8       700  16     USA      40    Tuesday
# 8     9      1200  27     USA      52  Wednesday

# %%
df4.drop(df4.columns[5], 1)
# using positions similar to labels it is also inplace
# Out:
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_3228\1667724466.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df4.drop(df4.columns[5], 1)
#    Date  Visitors  BR    Country  Clicks
# 0     1      1500  20        USA      20
# 1     2       700  25         UK      35
# 2     3       900  15      India      37
# 3     4       400  35        USA      12
# 4     5       500  14     Canada      35
# 5     6       700  15      India      32
# 6     7       600  20      India      37
# 7     8       700  16        USA      40
# 8     9      1200  27        USA      52
# 9    10      1400  32  Australia      57

# %%
# Updating values in rows and columns

# %%
df4["Status"] = ["F"] *10 # I have to provide 10 values as our table has 10 rows

# %%
df4
# Out:
#    Date  Visitors  BR    Country  Clicks        Day Status
# 0     1      1500  20        USA      20    Tuesday      F
# 1     2       700  25         UK      35  Wednesday      F
# 2     3       900  15      India      37   Thursday      F
# 3     4       400  35        USA      12     Friday      F
# 4     5       500  14     Canada      35   Saturday      F
# 5     6       700  15      India      32     Sunday      F
# 6     7       600  20      India      37     Monday      F
# 7     8       700  16        USA      40    Tuesday      F
# 8     9      1200  27        USA      52  Wednesday      F
# 9    10      1400  32  Australia      57   Thursday      F

# %%
# shape method provides the size of dataframe
df4.shape
# Out:
# (10, 7)

# %%
df4
# Out:
#    Date  Visitors  BR    Country  Clicks        Day Status    Test
# 0     1      1500  20        USA      20    Tuesday      F  ashish
# 1     2       700  25         UK      35  Wednesday      F  ashish
# 2     3       900  15      India      37   Thursday      F  ashish
# 3     4       400  35        USA      12     Friday      F  ashish
# 4     5       500  14     Canada      35   Saturday      F  ashish
# 5     6       700  15      India      32     Sunday      F  ashish
# 6     7       600  20      India      37     Monday      F  ashish
# 7     8       700  16        USA      40    Tuesday      F  ashish
# 8     9      1200  27        USA      52  Wednesday      F  ashish
# 9    10      1400  32  Australia      57   Thursday      F  ashish

# %%
#  You can use this to fill the data
df4["Test"] = ["ashish"] * df4.shape[0]

# %%
# Add something to day column
df4["Day"] = df4["Day"] + " October"
df4
# Out:
#    Date  Visitors  BR    Country  Clicks                                 Day  \
# 0     1      1500  20        USA      20    Tuesday October, October October
# 1     2       700  25         UK      35  Wednesday October, October October
# 2     3       900  15      India      37   Thursday October, October October
# 3     4       400  35        USA      12     Friday October, October October
# 4     5       500  14     Canada      35   Saturday October, October October
# 5     6       700  15      India      32     Sunday October, October October
# 6     7       600  20      India      37     Monday October, October October
# 7     8       700  16        USA      40    Tuesday October, October October
# 8     9      1200  27        USA      52  Wednesday October, October October
# 9    10      1400  32  Australia      57   Thursday October, October October
#
#   Status    Test
# 0      F  ashish
# 1      F  ashish
# 2      F  ashish
# 3      F  ashish
# 4      F  ashish
# ...

# %%
df6 = df4.T
df6
# Out:
#                                          0  \
# Date                                     1
# Visitors                              1500
# BR                                      20
# Country                                USA
# Clicks                                  20
# Day       Tuesday October, October October
# Status                                   F
# Test                                ashish
#
#                                            1  \
# Date                                       2
# Visitors                                 700
# BR                                        25
# Country                                   UK
# Clicks                                    35
# Day       Wednesday October, October October
# Status                                     F
# Test                                  ashish
#
#                                           2                                3  \
# Date                                      3                                4
# ...

# %%
# Now add the data in columns way and again reverse the dataframe
